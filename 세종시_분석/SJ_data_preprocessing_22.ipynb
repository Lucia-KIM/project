# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_in = pd.read_csv('/Users/lucia/Downloads/20.세종시_전입자수.csv', encoding='utf-8')
df_in
# Out:
#             년월  전입자수 세종전입행정동   전출시   전출시군구   전출읍면동
# 0       201701     1    조치원읍   강원도     강릉시     교1동
# 1       201701     6    조치원읍   강원도     동해시     천곡동
# 2       201701    14    조치원읍   강원도     속초시      교동
# 3       201701    21    조치원읍   강원도     양양군      서면
# 4       201701     2    조치원읍   강원도     원주시     원인동
# ...        ...   ...     ...   ...     ...     ...
# 108077  202101     3     다정동  충청북도  청주시흥덕구    복대1동
# 108078  202101    56     다정동  충청북도  청주시흥덕구     오송읍
# 108079  202101    32     다정동  충청북도  청주시흥덕구     옥산면
# 108080  202101     8     다정동  충청북도     충주시  교현·안림동
# 108081  202101     9     다정동  충청북도     충주시    중앙탑면
#
# [108082 rows x 6 columns]

# %%
df_in['국가'] = '대한민국'
df_in['전입시'] = '세종특별자치시'
df_in
# Out:
#             년월  전입자수 세종전입행정동   전출시   전출시군구   전출읍면동    국가      전입시
# 0       201701     1    조치원읍   강원도     강릉시     교1동  대한민국  세종특별자치시
# 1       201701     6    조치원읍   강원도     동해시     천곡동  대한민국  세종특별자치시
# 2       201701    14    조치원읍   강원도     속초시      교동  대한민국  세종특별자치시
# 3       201701    21    조치원읍   강원도     양양군      서면  대한민국  세종특별자치시
# 4       201701     2    조치원읍   강원도     원주시     원인동  대한민국  세종특별자치시
# ...        ...   ...     ...   ...     ...     ...   ...      ...
# 108077  202101     3     다정동  충청북도  청주시흥덕구    복대1동  대한민국  세종특별자치시
# 108078  202101    56     다정동  충청북도  청주시흥덕구     오송읍  대한민국  세종특별자치시
# 108079  202101    32     다정동  충청북도  청주시흥덕구     옥산면  대한민국  세종특별자치시
# 108080  202101     8     다정동  충청북도     충주시  교현·안림동  대한민국  세종특별자치시
# 108081  202101     9     다정동  충청북도     충주시    중앙탑면  대한민국  세종특별자치시
#
# [108082 rows x 8 columns]

# %%
df_in.to_csv('df_in.csv', encoding='utf-8')

# %%
df_date = df_in.groupby(['년월','세종전입행정동']).count()
df_date
# Out:
#                 전입자수  전출시  전출시군구  전출읍면동   국가
# 년월     세종전입행정동
# 201701 금남면        74   74     74     74   74
#        도담동       310  310    310    310  310
#        부강면        58   58     58     58   58
#        소정면        15   15     15     15   15
#        아름동       258  258    258    258  258
# ...              ...  ...    ...    ...  ...
# 202101 전동면        18   18     18     18   18
#        전의면        38   38     38     38   38
#        조치원읍      267  267    267    267  267
#        종촌동       154  154    154    154  154
#        한솔동       112  112    112    112  112
#
# [894 rows x 5 columns]

# %%
df_2017 = (df_in['년월']=='\^2017')
df_2017
# Out:
# /Users/lucia/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pandas/core/computation/expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 108077    False
# 108078    False
# 108079    False
# 108080    False
# 108081    False
# Name: 년월, Length: 108082, dtype: bool

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('/Users/lucia/Downloads/22.세종시_연령별_인구현황.csv', encoding='utf8')
df = df.T
df
# Out:
#                          0      1     2     3     4     5     6     7     8   \
# 읍면동                 세종특별자치시   조치원읍   연기면   연동면   부강면   금남면   장군면   연서면   전의면
# 201701_남자(총_거주자_수)   121937  23529  1463  1828  3554  5033  3427  4182  3312
# 201701_남자(연령구간인구수)   121937  23529  1463  1828  3554  5033  3427  4182  3312
# 201701_남자(0~9세)       17864   2525    56    87   235   263   132   222   194
# 201701_남자(10~19세)     13917   2473    93   123   287   287   199   328   285
# ...                     ...    ...   ...   ...   ...   ...   ...   ...   ...
# 202012_여자(60~69세)     15113   2676   221   307   511   836   514   657   453
# 202012_여자(70~79세)      7736   1725   138   224   353   606   302   517   377
# 202012_여자(80~89세)      4672    930   102   212   251   437   244   338   300
# 202012_여자(90~99세)       915    162    23    45    32    91    38    54    60
# 202012_여자(100세_이상)       22      7     1     0     1     2     1     2     1
#
# ...

# %%
df_byMonth_bySex = df.iloc[:2]
df_byMonth_bySex


# 필요한 내용만 담은 데이터프레임 추출
for i in range(14, 1249, 13):
    df_byMonth_bySex = pd.concat([df_byMonth_bySex, pd.DataFrame(df.iloc[i]).T], axis=0)

df_byMonth_bySex
# Out:
#                          0      1     2     3     4     5     6     7     8   \
# 읍면동                 세종특별자치시   조치원읍   연기면   연동면   부강면   금남면   장군면   연서면   전의면
# 201701_남자(총_거주자_수)   121937  23529  1463  1828  3554  5033  3427  4182  3312
# 201701_여자(총_거주자_수)   121988  22496  1217  1751  3150  4606  2819  3721  3095
# 201702_남자(총_거주자_수)   123257  23526  1463  1817  3555  5039  3451  4211  3314
# 201702_여자(총_거주자_수)   123344  22495  1221  1741  3126  4578  2830  3738  3088
# ...                     ...    ...   ...   ...   ...   ...   ...   ...   ...
# 202010_여자(총_거주자_수)   175323  20681  1132  1498  2748  4130  2837  3401  2622
# 202011_남자(총_거주자_수)   175768  22071  1498  1628  3402  4604  3765  4025  2961
# 202011_여자(총_거주자_수)   176541  20649  1151  1492  2755  4173  2856  3385  2614
# 202012_남자(총_거주자_수)   176998  22136  1512  1628  3412  4616  3785  4046  2979
# 202012_여자(총_거주자_수)   177707  20653  1159  1495  2784  4174  2836  3388  2611
#
# ...

# %%
# df_byMonth_bySex.T

# %%
df_byMonth_bySex.columns = ['세종특별자치시', '조치원읍','연기면','연동면','부강면','금남면','장군면','연서면','전의면','전동면','소정면','한솔동','새롬동','도담동','아름동','종촌동','고운동','소담동','보람동','대평동','다정동']
df_byMonth_bySex= df_byMonth_bySex.drop(df_byMonth_bySex.index[0])
df_byMonth_bySex
# Out:
#                    세종특별자치시   조치원읍   연기면   연동면   부강면   금남면   장군면   연서면   전의면  \
# 201701_남자(총_거주자_수)  121937  23529  1463  1828  3554  5033  3427  4182  3312
# 201701_여자(총_거주자_수)  121988  22496  1217  1751  3150  4606  2819  3721  3095
# 201702_남자(총_거주자_수)  123257  23526  1463  1817  3555  5039  3451  4211  3314
# 201702_여자(총_거주자_수)  123344  22495  1221  1741  3126  4578  2830  3738  3088
# 201703_남자(총_거주자_수)  124996  23534  1462  1822  3529  5044  3476  4208  3313
# ...                    ...    ...   ...   ...   ...   ...   ...   ...   ...
# 202010_여자(총_거주자_수)  175323  20681  1132  1498  2748  4130  2837  3401  2622
# 202011_남자(총_거주자_수)  175768  22071  1498  1628  3402  4604  3765  4025  2961
# 202011_여자(총_거주자_수)  176541  20649  1151  1492  2755  4173  2856  3385  2614
# 202012_남자(총_거주자_수)  176998  22136  1512  1628  3412  4616  3785  4046  2979
# 202012_여자(총_거주자_수)  177707  20653  1159  1495  2784  4174  2836  3388  2611
#
# ...

# %%
df_byMonth_bySex.index[0][:6]
# Out:
# '201701'

# %%
date = []

for i in range(0, 96):
    date.append(df_byMonth_bySex.index[i][:6])
    
date
# Out:
# ['201701',
#  '201701',
#  '201702',
#  '201702',
#  '201703',
#  '201703',
#  '201704',
#  '201704',
#  '201705',
#  '201705',
#  '201706',
#  '201706',
#  '201707',
#  '201707',
#  '201708',
#  '201708',
#  '201709',
#  '201709',
#  '201710',
#  '201710',
#  '201711',
#  '201711',
#  '201712',
#  '201712',
#  '201801',
#  '201801',
#  '201802',
#  '201802',
#  '201803',
#  '201803',
#  '201804',
#  '201804',
#  '201805',
#  '201805',
#  '201806',
#  '201806',
#  '201807',
#  '201807',
#  '201808',
#  '201808',
#  '201809',
#  '201809',
#  '201810',
#  '201810',
#  '201811',
#  '201811',
#  '201812',
#  '201812',
#  '201901',
#  '201901',
#  '201902',
#  '201902',
#  '201903',
#  '201903',
#  '201904',
#  '201904',
#  '201905',
#  '201905',
#  '201906',
#  '201906',
#  '201907',
#  '201907',
#  '201908',
#  '201908',
#  '201909',
#  '201909',
#  '201910',
#  '201910',
#  '201911',
#  '201911',
#  '201912',
#  '201912',
#  '202001',
#  '202001',
#  '202002',
#  '202002',
# ...

# %%
df_byMonth_bySex['년월'] = date

# %%
sex = []

for i in range(0, 96):
    sex.append(df_byMonth_bySex.index[i][7:9])
    

sex
# Out:
# ['남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자',
#  '남자',
#  '여자']

# %%
df_byMonth_bySex['성별'] = sex
df_byMonth_bySex
# Out:
#                    세종특별자치시   조치원읍   연기면   연동면   부강면   금남면   장군면   연서면   전의면  \
# 201701_남자(총_거주자_수)  121937  23529  1463  1828  3554  5033  3427  4182  3312
# 201701_여자(총_거주자_수)  121988  22496  1217  1751  3150  4606  2819  3721  3095
# 201702_남자(총_거주자_수)  123257  23526  1463  1817  3555  5039  3451  4211  3314
# 201702_여자(총_거주자_수)  123344  22495  1221  1741  3126  4578  2830  3738  3088
# 201703_남자(총_거주자_수)  124996  23534  1462  1822  3529  5044  3476  4208  3313
# ...                    ...    ...   ...   ...   ...   ...   ...   ...   ...
# 202010_여자(총_거주자_수)  175323  20681  1132  1498  2748  4130  2837  3401  2622
# 202011_남자(총_거주자_수)  175768  22071  1498  1628  3402  4604  3765  4025  2961
# 202011_여자(총_거주자_수)  176541  20649  1151  1492  2755  4173  2856  3385  2614
# 202012_남자(총_거주자_수)  176998  22136  1512  1628  3412  4616  3785  4046  2979
# 202012_여자(총_거주자_수)  177707  20653  1159  1495  2784  4174  2836  3388  2611
#
# ...

# %%
df_byMonth_bySex.set_index(df_byMonth_bySex['년월'], drop=True, inplace=True)

df_byMonth_bySex
# Out:
#        세종특별자치시   조치원읍   연기면   연동면   부강면   금남면   장군면   연서면   전의면   전동면  ...  \
# 년월                                                                     ...
# 201701  121937  23529  1463  1828  3554  5033  3427  4182  3312  2124  ...
# 201701  121988  22496  1217  1751  3150  4606  2819  3721  3095  1801  ...
# 201702  123257  23526  1463  1817  3555  5039  3451  4211  3314  2125  ...
# 201702  123344  22495  1221  1741  3126  4578  2830  3738  3088  1792  ...
# 201703  124996  23534  1462  1822  3529  5044  3476  4208  3313  2127  ...
# ...        ...    ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 202010  175323  20681  1132  1498  2748  4130  2837  3401  2622  1625  ...
# 202011  175768  22071  1498  1628  3402  4604  3765  4025  2961  1914  ...
# 202011  176541  20649  1151  1492  2755  4173  2856  3385  2614  1619  ...
# 202012  176998  22136  1512  1628  3412  4616  3785  4046  2979  1903  ...
# ...

# %%
# del df_byMonth_bySex['년월']
# df_byMonth_bySex

# %%
df_byMonth_bySex = df_byMonth_bySex[['년월','성별','세종특별자치시', '조치원읍','연기면','연동면','부강면','금남면','장군면','연서면','전의면','전동면','소정면','한솔동','새롬동','도담동','아름동','종촌동','고운동','소담동','보람동','대평동','다정동']]
df_byMonth_bySex
# Out:
#             년월  성별 세종특별자치시   조치원읍   연기면   연동면   부강면   금남면   장군면   연서면  ...  \
# 년월                                                                     ...
# 201701  201701  남자  121937  23529  1463  1828  3554  5033  3427  4182  ...
# 201701  201701  여자  121988  22496  1217  1751  3150  4606  2819  3721  ...
# 201702  201702  남자  123257  23526  1463  1817  3555  5039  3451  4211  ...
# 201702  201702  여자  123344  22495  1221  1741  3126  4578  2830  3738  ...
# 201703  201703  남자  124996  23534  1462  1822  3529  5044  3476  4208  ...
# ...        ...  ..     ...    ...   ...   ...   ...   ...   ...   ...  ...
# 202010  202010  여자  175323  20681  1132  1498  2748  4130  2837  3401  ...
# 202011  202011  남자  175768  22071  1498  1628  3402  4604  3765  4025  ...
# 202011  202011  여자  176541  20649  1151  1492  2755  4173  2856  3385  ...
# 202012  202012  남자  176998  22136  1512  1628  3412  4616  3785  4046  ...
# ...

# %%
# 엑셀파일로 저장 
# df_byMonth_bySex.to_excel('df_byMonth_bySex.xlsx')
# df_byMonth_bySex.to_csv('df_byMonth_bySex.csv', encoding='utf-8')

# %%
df_byMonth_bySex.reset_index(drop=True, inplace=True)
df_byMonth_bySex.head(40)

df_byMonth_bySex.to_csv('df_byMonth_bySex.csv', encoding='utf-8')

# %% [markdown]
# # 합계 자료 없는 데이터 생성

# %%
raw_pop = df.iloc[3:14]
# raw_pop


# 필요한 내용만 담은 데이터프레임 추출
for i in range(16, 1249, 13):
    raw_pop = pd.concat([raw_pop, df.iloc[i:i+11]], axis=0)

raw_pop
# Out:
#                    세종특별자치시  조치원읍  연기면  연동면  부강면  금남면  장군면  연서면  전의면  전동면  ...  \
# 201701_남자(0~9세)      17864  2525   56   87  235  263  132  222  194   67  ...
# 201701_남자(10~19세)    13917  2473   93  123  287  287  199  328  285   97  ...
# 201701_남자(20~29세)    13463  3461  220  210  472  616  540  532  403  245  ...
# 201701_남자(30~39세)    22372  3783  176  228  505  620  510  526  392  225  ...
# 201701_남자(40~49세)    23665  4126  263  247  588  767  574  616  520  289  ...
# ...                    ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 202012_여자(60~69세)    15113  2676  221  307  511  836  514  657  453  374  ...
# 202012_여자(70~79세)     7736  1725  138  224  353  606  302  517  377  259  ...
# 202012_여자(80~89세)     4672   930  102  212  251  437  244  338  300  208  ...
# 202012_여자(90~99세)      915   162   23   45   32   91   38   54   60   41  ...
# 202012_여자(100세_이상)      22     7    1    0    1    2    1    2    1    2  ...
#
# ...

# %%
pre_df = raw_pop
pre_df
# Out:
#                    세종특별자치시  조치원읍  연기면  연동면  부강면  금남면  장군면  연서면  전의면  전동면  ...  \
# 201701_남자(0~9세)      17864  2525   56   87  235  263  132  222  194   67  ...
# 201701_남자(10~19세)    13917  2473   93  123  287  287  199  328  285   97  ...
# 201701_남자(20~29세)    13463  3461  220  210  472  616  540  532  403  245  ...
# 201701_남자(30~39세)    22372  3783  176  228  505  620  510  526  392  225  ...
# 201701_남자(40~49세)    23665  4126  263  247  588  767  574  616  520  289  ...
# ...                    ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 202012_여자(60~69세)    15113  2676  221  307  511  836  514  657  453  374  ...
# 202012_여자(70~79세)     7736  1725  138  224  353  606  302  517  377  259  ...
# 202012_여자(80~89세)     4672   930  102  212  251  437  244  338  300  208  ...
# 202012_여자(90~99세)      915   162   23   45   32   91   38   54   60   41  ...
# 202012_여자(100세_이상)      22     7    1    0    1    2    1    2    1    2  ...
#
# ...

# %%
# pre_df.columns = ['세종특별자치시', '조치원읍','연기면','연동면','부강면','금남면','장군면','연서면','전의면','전동면','소정면','한솔동','새롬동','도담동','아름동','종촌동','고운동','소담동','보람동','대평동','다정동']
# pre_df= pre_df.drop(pre_df.index[0])
# pre_df

# %%
pre_df.count()
# Out:
# 세종특별자치시    1056
# 조치원읍       1056
# 연기면        1056
# 연동면        1056
# 부강면        1056
# 금남면        1056
# 장군면        1056
# 연서면        1056
# 전의면        1056
# 전동면        1056
# 소정면        1056
# 한솔동        1056
# 새롬동        1056
# 도담동        1056
# 아름동        1056
# 종촌동        1056
# 고운동        1056
# 소담동        1056
# 보람동        1056
# 대평동        1056
# 다정동        1056
# dtype: int64

# %%
# pre_df.index[1][:6]

date = []

for i in range(0, 1056):
    date.append(pre_df.index[i][:6])
    
len(date)
# Out:
# 1056

# %%
pre_df['년월'] = date

# %%
pre_df.tail()
# Out:
#                    세종특별자치시  조치원읍  연기면  연동면  부강면  금남면  장군면  연서면  전의면  전동면  ...  \
# 202012_여자(60~69세)    15113  2676  221  307  511  836  514  657  453  374  ...
# 202012_여자(70~79세)     7736  1725  138  224  353  606  302  517  377  259  ...
# 202012_여자(80~89세)     4672   930  102  212  251  437  244  338  300  208  ...
# 202012_여자(90~99세)      915   162   23   45   32   91   38   54   60   41  ...
# 202012_여자(100세_이상)      22     7    1    0    1    2    1    2    1    2  ...
#
#                     새롬동   도담동  아름동   종촌동   고운동  소담동  보람동  대평동  다정동      년월
# 202012_여자(60~69세)   839  1190  613  1049  1240  901  672  418  845  202012
# 202012_여자(70~79세)   281   550  237   432   429  308  220  114  243  202012
# 202012_여자(80~89세)   139   322  107   225   145  143  109   80  114  202012
# 202012_여자(90~99세)    40    69   27    30    37   42   28   24   28  202012
# 202012_여자(100세_이상)    0     0    0     0     0    3    0    0    0  202012
#
# [5 rows x 22 columns]

# %%
sex = []

for i in range(0, 1056):
    sex.append(pre_df.index[i][7:9])
    
sex
# Out:
# ['남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '남자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '여자',
#  '남자',
# ...

# %%
pre_df['성별'] = sex
pre_df
# Out:
#                    세종특별자치시  조치원읍  연기면  연동면  부강면  금남면  장군면  연서면  전의면  전동면  ...  \
# 201701_남자(0~9세)      17864  2525   56   87  235  263  132  222  194   67  ...
# 201701_남자(10~19세)    13917  2473   93  123  287  287  199  328  285   97  ...
# 201701_남자(20~29세)    13463  3461  220  210  472  616  540  532  403  245  ...
# 201701_남자(30~39세)    22372  3783  176  228  505  620  510  526  392  225  ...
# 201701_남자(40~49세)    23665  4126  263  247  588  767  574  616  520  289  ...
# ...                    ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 202012_여자(60~69세)    15113  2676  221  307  511  836  514  657  453  374  ...
# 202012_여자(70~79세)     7736  1725  138  224  353  606  302  517  377  259  ...
# 202012_여자(80~89세)     4672   930  102  212  251  437  244  338  300  208  ...
# 202012_여자(90~99세)      915   162   23   45   32   91   38   54   60   41  ...
# 202012_여자(100세_이상)      22     7    1    0    1    2    1    2    1    2  ...
#
# ...

# %%
age = []

# df.index[3][9:]

for i in range(0, 1056):
    age.append(pre_df.index[i][9:])
    
age
# Out:
# ['(0~9세)',
#  '(10~19세)',
#  '(20~29세)',
#  '(30~39세)',
#  '(40~49세)',
#  '(50~59세)',
#  '(60~69세)',
#  '(70~79세)',
#  '(80~89세)',
#  '(90~99세)',
#  '(100세_이상)',
#  '(0~9세)',
#  '(10~19세)',
#  '(20~29세)',
#  '(30~39세)',
#  '(40~49세)',
#  '(50~59세)',
#  '(60~69세)',
#  '(70~79세)',
#  '(80~89세)',
#  '(90~99세)',
#  '(100세_이상)',
#  '(0~9세)',
#  '(10~19세)',
#  '(20~29세)',
#  '(30~39세)',
#  '(40~49세)',
#  '(50~59세)',
#  '(60~69세)',
#  '(70~79세)',
#  '(80~89세)',
#  '(90~99세)',
#  '(100세_이상)',
#  '(0~9세)',
#  '(10~19세)',
#  '(20~29세)',
#  '(30~39세)',
#  '(40~49세)',
#  '(50~59세)',
#  '(60~69세)',
#  '(70~79세)',
#  '(80~89세)',
#  '(90~99세)',
#  '(100세_이상)',
#  '(0~9세)',
#  '(10~19세)',
#  '(20~29세)',
#  '(30~39세)',
#  '(40~49세)',
#  '(50~59세)',
#  '(60~69세)',
#  '(70~79세)',
#  '(80~89세)',
#  '(90~99세)',
#  '(100세_이상)',
#  '(0~9세)',
#  '(10~19세)',
#  '(20~29세)',
#  '(30~39세)',
#  '(40~49세)',
#  '(50~59세)',
#  '(60~69세)',
#  '(70~79세)',
#  '(80~89세)',
#  '(90~99세)',
#  '(100세_이상)',
#  '(0~9세)',
# ...

# %%
pre_df['연령대'] = age

# %%
# 컬럼 순서 재배열

pre_df = pre_df[['년월','성별','연령대','세종특별자치시', '조치원읍','연기면','연동면','부강면','금남면','장군면','연서면','전의면','전동면','소정면','한솔동','새롬동','도담동','아름동','종촌동','고운동','소담동','보람동','대평동','다정동']]
pre_df
# Out:
#                         년월  성별        연령대 세종특별자치시  조치원읍  연기면  연동면  부강면  금남면  \
# 201701_남자(0~9세)     201701  남자     (0~9세)   17864  2525   56   87  235  263
# 201701_남자(10~19세)   201701  남자   (10~19세)   13917  2473   93  123  287  287
# 201701_남자(20~29세)   201701  남자   (20~29세)   13463  3461  220  210  472  616
# 201701_남자(30~39세)   201701  남자   (30~39세)   22372  3783  176  228  505  620
# 201701_남자(40~49세)   201701  남자   (40~49세)   23665  4126  263  247  588  767
# ...                    ...  ..        ...     ...   ...  ...  ...  ...  ...
# 202012_여자(60~69세)   202012  여자   (60~69세)   15113  2676  221  307  511  836
# 202012_여자(70~79세)   202012  여자   (70~79세)    7736  1725  138  224  353  606
# 202012_여자(80~89세)   202012  여자   (80~89세)    4672   930  102  212  251  437
# 202012_여자(90~99세)   202012  여자   (90~99세)     915   162   23   45   32   91
# 202012_여자(100세_이상)  202012  여자  (100세_이상)      22     7    1    0    1    2
#
# ...

# %%
pre_df = pre_df.reset_index(drop=True)
pre_df.head(20)
# Out:
#         년월  성별        연령대 세종특별자치시  조치원읍  연기면  연동면  부강면   금남면  장군면  ...   한솔동  \
# 0   201701  남자     (0~9세)   17864  2525   56   87  235   263  132  ...  3185
# 1   201701  남자   (10~19세)   13917  2473   93  123  287   287  199  ...  2466
# 2   201701  남자   (20~29세)   13463  3461  220  210  472   616  540  ...  1760
# 3   201701  남자   (30~39세)   22372  3783  176  228  505   620  510  ...  3364
# 4   201701  남자   (40~49세)   23665  4126  263  247  588   767  574  ...  3790
# 5   201701  남자   (50~59세)   15288  3393  296  368  650  1013  648  ...  1833
# 6   201701  남자   (60~69세)    8922  2131  203  318  396   814  451  ...   662
# 7   201701  남자   (70~79세)    4631  1214  112  156  290   454  258  ...   245
# 8   201701  남자   (80~89세)    1683   389   38   87  124   181  111  ...    62
# 9   201701  남자   (90~99세)     132    34    6    4    7    18    4  ...     9
# 10  201701  남자  (100세_이상)       0     0    0    0    0     0    0  ...     0
# ...

# %%
pre_df.to_csv('pre_df.csv', encoding='utf-8')
