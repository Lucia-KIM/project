# %%
import pandas as pd 
import numpy as np 
#시각화
import matplotlib.pyplot as plt
import seaborn as sns
#경고무시
import sys
import warnings

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'AppleGothic' # 맥(Mac) 사용자

# %%
df = pd.read_excel('./클로젯셰어_과제DB 대체 자료.xlsx', engine='openpyxl')
df
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1466   Yves Saint Laurent                 logo point clutch bag pink
# 1467                Prada                        saffiano lux M gray
# 1468             Burberry                basic pattern sweater beige
# 1469               Chanel        graphics pattern sweat-shirts white
# 1470             Burberry                  classic trench coat beige
#
#           USER   reg_date order_date p_type sub_type app_yn
# 0      a161237 2019-12-06 2021-01-15  7days       BA      Y
# 1     a1140859 2021-01-02 2021-01-15  4days        O    NaN
# 2     a1140859 2021-01-02 2021-01-15  4days        B    NaN
# 3     a1140859 2021-01-02 2021-01-15  4days        T    NaN
# 4     a1140740 2021-01-01 2021-01-15  7days        O      Y
# ...        ...        ...        ...    ...      ...    ...
# 1466   a119721 2019-04-10 2021-03-01  7days       BA      Y
# 1467  a1146069 2021-02-11 2021-03-01  7days       BA      Y
# 1468  a1147848 2021-02-28 2021-03-01  7days        T      Y
# 1469  a1147788 2021-02-28 2021-03-01  7days        T      Y
# 1470   a190054 2020-03-24 2021-03-01  4days        O      Y
#
# [1471 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   brandnm     1442 non-null   object
#  1   goodsnm     1471 non-null   object
#  2   USER        1471 non-null   object
#  3   reg_date    1466 non-null   datetime64[ns]
#  4   order_date  1471 non-null   datetime64[ns]
#  5   p_type      1471 non-null   object
#  6   sub_type    1471 non-null   object
#  7   app_yn      1295 non-null   object
# dtypes: datetime64[ns](2), object(6)
# memory usage: 92.1+ KB

# %% [markdown]
# ##  2-1. 유저당 주문 수량 분석
# 최근 3개월 전체 분석 / 각 월 별 분석

# %%
usr = list(df.USER.unique())
# usr  # 고객명단

# %%
df.groupby('USER').count()

# 전체 행이 1471인데, 고객별로 묶으면, 1234행
# Out:
#           brandnm  goodsnm  reg_date  order_date  p_type  sub_type  app_yn
# USER
# a1100548        2        2         2           2       2         2       2
# a1100887        1        1         1           1       1         1       1
# a1101514        1        1         1           1       1         1       1
# a1101645        1        1         1           1       1         1       0
# a1102068        1        1         1           1       1         1       1
# ...           ...      ...       ...         ...     ...       ...     ...
# a198621         1        1         1           1       1         1       1
# a19897          1        1         1           1       1         1       0
# a199351         1        1         1           1       1         1       1
# a199421         1        1         1           1       1         1       1
# a19983          1        1         1           1       1         1       1
#
# [1234 rows x 7 columns]

# %%
df.groupby('USER').count().sort_values(by='p_type', ascending=False)
# Out:
#           brandnm  goodsnm  reg_date  order_date  p_type  sub_type  app_yn
# USER
# a1149461       11       11        11          11      11        11       0
# a1149583       10       10        10          10      10        10       0
# a1142677        9        9         9           9       9         9       9
# a1143701        7        7         7           7       7         7       7
# a189404         7        7         7           7       7         7       7
# ...           ...      ...       ...         ...     ...       ...     ...
# a1145218        1        1         1           1       1         1       1
# a1145217        1        1         1           1       1         1       1
# a1145206        1        1         1           1       1         1       1
# a1145200        1        1         1           1       1         1       1
# a19983          1        1         1           1       1         1       1
#
# [1234 rows x 7 columns]

# %% [markdown]
# ### 2-1. Q1>  최근 3개월 전체 분석

# %%
df['order_day'] = df.order_date.dt.weekday  # 주문 요일 넣어주기 (월=0)
df
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1466   Yves Saint Laurent                 logo point clutch bag pink
# 1467                Prada                        saffiano lux M gray
# 1468             Burberry                basic pattern sweater beige
# 1469               Chanel        graphics pattern sweat-shirts white
# 1470             Burberry                  classic trench coat beige
#
#           USER   reg_date order_date p_type sub_type app_yn  order_day
# 0      a161237 2019-12-06 2021-01-15  7days       BA      Y          4
# 1     a1140859 2021-01-02 2021-01-15  4days        O    NaN          4
# 2     a1140859 2021-01-02 2021-01-15  4days        B    NaN          4
# 3     a1140859 2021-01-02 2021-01-15  4days        T    NaN          4
# 4     a1140740 2021-01-01 2021-01-15  7days        O      Y          4
# ...        ...        ...        ...    ...      ...    ...        ...
# 1466   a119721 2019-04-10 2021-03-01  7days       BA      Y          0
# 1467  a1146069 2021-02-11 2021-03-01  7days       BA      Y          0
# 1468  a1147848 2021-02-28 2021-03-01  7days        T      Y          0
# 1469  a1147788 2021-02-28 2021-03-01  7days        T      Y          0
# 1470   a190054 2020-03-24 2021-03-01  4days        O      Y          0
#
# [1471 rows x 9 columns]

# %%
# 공휴일은 요일 구분 중 7로 바꿔서 따로 살펴볼 예정 
holiday_list = ['2021-01-01', '2021-02-11', '2021-02-12', '2021-02-13', '2021-03-01']

for i in range(len(df)) :
    if df['order_date'].loc[i].strftime('%Y-%m-%d') in holiday_list :
        df['order_day'].loc[i] = 7
        
df
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1466   Yves Saint Laurent                 logo point clutch bag pink
# 1467                Prada                        saffiano lux M gray
# 1468             Burberry                basic pattern sweater beige
# 1469               Chanel        graphics pattern sweat-shirts white
# 1470             Burberry                  classic trench coat beige
#
#           USER   reg_date order_date p_type sub_type app_yn  order_day
# 0      a161237 2019-12-06 2021-01-15  7days       BA      Y          4
# 1     a1140859 2021-01-02 2021-01-15  4days        O    NaN          4
# 2     a1140859 2021-01-02 2021-01-15  4days        B    NaN          4
# 3     a1140859 2021-01-02 2021-01-15  4days        T    NaN          4
# 4     a1140740 2021-01-01 2021-01-15  7days        O      Y          4
# ...        ...        ...        ...    ...      ...    ...        ...
# 1466   a119721 2019-04-10 2021-03-01  7days       BA      Y          7
# 1467  a1146069 2021-02-11 2021-03-01  7days       BA      Y          7
# 1468  a1147848 2021-02-28 2021-03-01  7days        T      Y          7
# 1469  a1147788 2021-02-28 2021-03-01  7days        T      Y          7
# 1470   a190054 2020-03-24 2021-03-01  4days        O      Y          7
#
# [1471 rows x 9 columns]

# %%
a = df.USER.value_counts()
for i in range(1, 12):
    if len(a[a.values > i]) != 0:
        print('전체 이용 고객 중 {}개 이상 빌린 고객 수 : '.format(i+1), len(a[a.values > i]))
    else:
        break
# Out:
# 전체 이용 고객 중 2개 이상 빌린 고객 수 :  139
# 전체 이용 고객 중 3개 이상 빌린 고객 수 :  50
# 전체 이용 고객 중 4개 이상 빌린 고객 수 :  17
# 전체 이용 고객 중 5개 이상 빌린 고객 수 :  9
# 전체 이용 고객 중 6개 이상 빌린 고객 수 :  8
# 전체 이용 고객 중 7개 이상 빌린 고객 수 :  5
# 전체 이용 고객 중 8개 이상 빌린 고객 수 :  3
# 전체 이용 고객 중 9개 이상 빌린 고객 수 :  3
# 전체 이용 고객 중 10개 이상 빌린 고객 수 :  2
# 전체 이용 고객 중 11개 이상 빌린 고객 수 :  1

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=df, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=df, x='order_day', hue='p_type')
plt.title('p_type별 요일별 주문건')

plt.subplot(223)
sns.countplot(data=df, x='order_day', hue='sub_type')
plt.title('sub_type별 요일별 주문건')

plt.subplot(224)
sns.countplot(data=df, x='order_day', hue='app_yn')
plt.title('앱 유입여부')

plt.suptitle('2021년 1분기 전체 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %%
# 10회 이상 구매한 고객 1 
df.query('USER=="a1149461"')
# 하루에 여러가지 옷을 렌트
# 촬영이나 상업적 이용이 있을지도
# Out:
#                   brandnm                                           goodsnm  \
# 1148       Alice & Olivia              see-through lace detail blouse black
# 1149               Sandro                embroidery detail lace skirt multi
# 1150                 Time                    draping detail midi skirt gray
# 1151  El estilo de Claire     ruffle detail see-through sleeve blouse black
# 1152            It michaa                  pocket basic pattern skirt green
# 1153               roajeu  ruffle basic pattern mermaid trumpet-skirt green
# 1154       Alexander Wang                          basic pattern skirt grey
# 1155       Christian Dior                    basic pattern sweater burgundy
# 1156                 MSGM                           basic pattern top black
# 1157              Fayewoo     ruffle lace pattern mermaid trumpet-skirt red
# 1158                 Debb                 ribbon basic pattern blouse brown
#
#           USER   reg_date order_date p_type sub_type app_yn
# 1148  a1149461 2021-03-15 2021-03-17  4days        T    NaN
# 1149  a1149461 2021-03-15 2021-03-17  4days        B    NaN
# 1150  a1149461 2021-03-15 2021-03-17  4days        B    NaN
# 1151  a1149461 2021-03-15 2021-03-17  4days        T    NaN
# 1152  a1149461 2021-03-15 2021-03-17  4days        B    NaN
# 1153  a1149461 2021-03-15 2021-03-17  4days        B    NaN
# 1154  a1149461 2021-03-15 2021-03-17  4days        B    NaN
# 1155  a1149461 2021-03-15 2021-03-17  4days        T    NaN
# 1156  a1149461 2021-03-15 2021-03-17  4days        T    NaN
# 1157  a1149461 2021-03-15 2021-03-17  4days        B    NaN
# 1158  a1149461 2021-03-15 2021-03-17  4days        T    NaN

# %%
# 10회 이상 구매한 고객 2 
df.query('USER=="a1149583"')
# 마찬가지로 하루에 여러 상품 렌트
# 앱 사용 x
# Out:
#                brandnm                               goodsnm      USER  \
# 1102            Theory                one button jacket gray  a1149583
# 1103            Michaa        stitch detail midi skirt white  a1149583
# 1104             Prada               daino shoulder bag skin  a1149583
# 1105         Ted Baker      pleats basic pattern blouse pink  a1149583
# 1106  La maille sezane        frill dots pattern blouse nude  a1149583
# 1107            Michaa  basic pattern A-Line knit-dress nude  a1149583
# 1108            Jigott     button basic pattern blouse white  a1149583
# 1109         It michaa      basic pattern H-Line dress white  a1149583
# 1110              Mine              basic pattern skirt pink  a1149583
# 1111              Mine  punching basic pattern skirt skyblue  a1149583
#
#        reg_date order_date p_type sub_type app_yn
# 1102 2021-03-16 2021-03-19  4days        O    NaN
# 1103 2021-03-16 2021-03-19  4days        B    NaN
# 1104 2021-03-16 2021-03-19  4days       BA    NaN
# 1105 2021-03-16 2021-03-19  4days        T    NaN
# 1106 2021-03-16 2021-03-19  4days        T    NaN
# 1107 2021-03-16 2021-03-19  4days        D    NaN
# 1108 2021-03-16 2021-03-19  4days        T    NaN
# 1109 2021-03-16 2021-03-19  4days        D    NaN
# 1110 2021-03-16 2021-03-19  4days        B    NaN
# 1111 2021-03-16 2021-03-19  4days        B    NaN

# %%
a = df.USER.value_counts()
# 3개 이상 이용한 고객의 선호 브랜드

more3 = list(a[a.values > 2].index)
more3

more3_df = df[df.USER==more3[0]]

for i in range(1,len(more3)):
    more3_df = pd.concat([more3_df, df[df.USER==more3[i]]])
more3_df


more3_df.brandnm.value_counts(ascending=False).head(5)
# more3_df.brandnm.value_counts(ascending=False).head(30)
# Out:
# Burberry               6
# El estilo de Claire    6
# Max Mara               6
# Christian Dior         5
# Burberry London        5
# Name: brandnm, dtype: int64

# %% [markdown]
# ### 2-1. Q2>  각 월별 유저 분석

# %%
df.order_date.dt.month.value_counts()
# Out:
# 3    639
# 2    455
# 1    377
# Name: order_date, dtype: int64

# %%
df.order_date.dt.month.value_counts().plot(kind='bar')
plt.title('월별 구매자 수')
plt.show()

# %% [markdown]
# ### -1월

# %%
# 2021. 1월에 구매한 사람

use_Jan = df[df.order_date.dt.month == 1]
use_Jan
# Out:
#                  brandnm                                      goodsnm  \
# 0                  Gucci           flower dionysus shoulder bag beige
# 1    El estilo de Claire                   beads cropped jacket black
# 2                  Danha    embroidery point oriental mini skirt blue
# 3                  Danha                    graphics pattern top pink
# 4        Burberry London       buckle basic pattern zipup-jumper navy
# ..                   ...                                          ...
# 372                Prada                     check pattern lined vest
# 373                  NaN        frill detail knit & dot pattern skirt
# 374          Thom Browne  button stripe pattern cashmere sweater grey
# 375        Louis Vuitton               strap basic pattern coat black
# 376                 Time             basic pattern H-Line dress black
#
#          USER   reg_date order_date p_type sub_type app_yn  order_day
# 0     a161237 2019-12-06 2021-01-15  7days       BA      Y          4
# 1    a1140859 2021-01-02 2021-01-15  4days        O    NaN          4
# 2    a1140859 2021-01-02 2021-01-15  4days        B    NaN          4
# 3    a1140859 2021-01-02 2021-01-15  4days        T    NaN          4
# 4    a1140740 2021-01-01 2021-01-15  7days        O      Y          4
# ..        ...        ...        ...    ...      ...    ...        ...
# 372   a160435 2019-12-03 2021-01-17  4days        T      Y          6
# 373   a171081 2020-01-06 2021-01-17  7days       TP      Y          6
# 374  a1136372 2020-12-10 2021-01-16  4days        T      Y          5
# 375  a1137705 2020-12-18 2021-01-16  7days        O      Y          5
# 376  a1139715 2020-12-24 2021-01-16  4days        D    NaN          5
#
# [377 rows x 9 columns]

# %%
use_Jan = df[df.order_date.dt.month == 1]
a = use_Jan.USER.value_counts()

for i in range(1, 12):
    if len(a[a.values > i]) != 0:
        print('{}월 이용 고객 중 {}개 이상 빌린 고객 수 : '.format(1, i+1), len(a[a.values > i]))
    else:
        break
# Out:
# 1월 이용 고객 중 2개 이상 빌린 고객 수 :  35
# 1월 이용 고객 중 3개 이상 빌린 고객 수 :  16
# 1월 이용 고객 중 4개 이상 빌린 고객 수 :  6
# 1월 이용 고객 중 5개 이상 빌린 고객 수 :  3
# 1월 이용 고객 중 6개 이상 빌린 고객 수 :  2
# 1월 이용 고객 중 7개 이상 빌린 고객 수 :  2
# 1월 이용 고객 중 8개 이상 빌린 고객 수 :  1
# 1월 이용 고객 중 9개 이상 빌린 고객 수 :  1

# %%
# 요일별 구매 분포

f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=use_Jan, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=use_Jan, x='order_day', hue='p_type')
plt.title('p_type별 요일별 주문건')

plt.subplot(223)
sns.countplot(data=use_Jan, x='order_day', hue='sub_type')
plt.title('sub_type별 요일별 주문건')

plt.subplot(224)
sns.countplot(data=use_Jan, x='order_day', hue='app_yn')
plt.title('앱 유입여부')

plt.suptitle('2021년 1월 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### -2월

# %%
use_Feb = df[df.order_date.dt.month == 2]
use_Feb
# Out:
#                  brandnm                              goodsnm      USER  \
# 377                Prada           high neck robe jumper gray  a1112637
# 378        Louis Vuitton       unbalance detail zip-up jumper  a1112637
# 379  El estilo de Claire         see-through lace dress black  a1147589
# 380      Banana Republic  pocket basic pattern cardigan khaki  a1147589
# 381        Audrey Tailor     pocket basic pattern slacks navy  a1147589
# ..                   ...                                  ...       ...
# 827                Gucci        pattern pointed a-line skirts  a1135235
# 828                Chloe                 faye small bag black  a1144998
# 829                Prada      button basic pattern coat black  a1144978
# 830        Saint Laurent          mini sunset chain bag black  a1145011
# 831                Gucci           jackie 1961 hobo bag brown  a1145076
#
#       reg_date order_date p_type sub_type app_yn  order_day
# 377 2020-08-16 2021-02-28  7days        O      Y          6
# 378 2020-08-16 2021-02-28  7days        O      Y          6
# 379 2021-02-25 2021-02-28  7days        D      Y          6
# 380 2021-02-25 2021-02-28  7days        O      Y          6
# 381 2021-02-25 2021-02-28  7days        B      Y          6
# ..         ...        ...    ...      ...    ...        ...
# 827 2020-12-04 2021-02-01  4days        B      Y          0
# 828 2021-01-31 2021-02-01  4days       BA    NaN          0
# 829 2021-01-31 2021-02-01  7days        O      Y          0
# 830 2021-01-31 2021-02-01  7days       BA      Y          0
# 831 2021-02-01 2021-02-01  7days       BA      Y          0
#
# [455 rows x 9 columns]

# %%
use_Feb = df[df.order_date.dt.month == 2]
a = use_Feb.USER.value_counts()

for i in range(1, 12):
    if len(a[a.values > i]) != 0:
        print('{}월 이용 고객 중 {}개 이상 빌린 고객 수 : '.format(2, i+1), len(a[a.values > i]))
    else:
        break
# Out:
# 2월 이용 고객 중 2개 이상 빌린 고객 수 :  47
# 2월 이용 고객 중 3개 이상 빌린 고객 수 :  17
# 2월 이용 고객 중 4개 이상 빌린 고객 수 :  4
# 2월 이용 고객 중 5개 이상 빌린 고객 수 :  1
# 2월 이용 고객 중 6개 이상 빌린 고객 수 :  1

# %%
# 요일별 구매 분포
# 2월 공휴일(7)은 설연휴임
# 설연휴 : 2월 11일 ~ 2월 13일(목요일 ~ 토요일)

f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=use_Feb, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=use_Feb, x='order_day', hue='p_type')
plt.title('p_type별 요일별 주문건')

plt.subplot(223)
sns.countplot(data=use_Feb, x='order_day', hue='sub_type')
plt.title('sub_type별 요일별 주문건')

plt.subplot(224)
sns.countplot(data=use_Feb, x='order_day', hue='app_yn')
plt.title('앱 유입여부')

plt.suptitle('2021년 2월 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### -3월

# %%
use_Mar = df[df.order_date.dt.month == 3]
use_Mar
# Out:
#                   brandnm                                  goodsnm      USER  \
# 832              Burberry  button check pattern H-Line dress multi  a1151196
# 833   El estilo de Claire          frill stripe knit cardigan muti  a1151564
# 834                Chanel                       tweed jacket brown  a1148120
# 835                 Chloe              round handle tote bag black   a117466
# 836                 Gucci           vintage web shoulder bag black   a110727
# ...                   ...                                      ...       ...
# 1466   Yves Saint Laurent               logo point clutch bag pink   a119721
# 1467                Prada                      saffiano lux M gray  a1146069
# 1468             Burberry              basic pattern sweater beige  a1147848
# 1469               Chanel      graphics pattern sweat-shirts white  a1147788
# 1470             Burberry                classic trench coat beige   a190054
#
#        reg_date order_date p_type sub_type app_yn  order_day
# 832  2021-03-28 2021-03-31  7days        D    NaN          2
# 833  2021-03-31 2021-03-31  7days        T    NaN          2
# 834  2021-03-03 2021-03-31  4days        O    NaN          2
# 835  2019-03-06 2021-03-31  4days       BA      Y          2
# 836  2018-10-27 2021-03-31  4days       BA    NaN          2
# ...         ...        ...    ...      ...    ...        ...
# 1466 2019-04-10 2021-03-01  7days       BA      Y          7
# 1467 2021-02-11 2021-03-01  7days       BA      Y          7
# 1468 2021-02-28 2021-03-01  7days        T      Y          7
# 1469 2021-02-28 2021-03-01  7days        T      Y          7
# 1470 2020-03-24 2021-03-01  4days        O      Y          7
#
# [639 rows x 9 columns]

# %%
use_Mar = df[df.order_date.dt.month == 3]
a = use_Mar.USER.value_counts()

for i in range(1, 12):
    if len(a[a.values > i]) != 0:
        print('{}월 이용 고객 중 {}개 이상 빌린 고객 수 : '.format(3, i+1), len(a[a.values > i]))
    else:
        break
# Out:
# 3월 이용 고객 중 2개 이상 빌린 고객 수 :  57
# 3월 이용 고객 중 3개 이상 빌린 고객 수 :  17
# 3월 이용 고객 중 4개 이상 빌린 고객 수 :  7
# 3월 이용 고객 중 5개 이상 빌린 고객 수 :  5
# 3월 이용 고객 중 6개 이상 빌린 고객 수 :  5
# 3월 이용 고객 중 7개 이상 빌린 고객 수 :  3
# 3월 이용 고객 중 8개 이상 빌린 고객 수 :  2
# 3월 이용 고객 중 9개 이상 빌린 고객 수 :  2
# 3월 이용 고객 중 10개 이상 빌린 고객 수 :  2
# 3월 이용 고객 중 11개 이상 빌린 고객 수 :  1

# %%
# 요일별 구매 분포
# 3월 공휴일(7)은 3.1절임, 삼일절은 월요일이었음 

f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=use_Mar, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=use_Mar, x='order_day', hue='p_type')
plt.title('p_type별 요일별 주문건')

plt.subplot(223)
sns.countplot(data=use_Mar, x='order_day', hue='sub_type')
plt.title('sub_type별 요일별 주문건')

plt.subplot(224)
sns.countplot(data=use_Mar, x='order_day', hue='app_yn')
plt.title('앱 유입여부')

plt.suptitle('2021년 3월 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ##  2-2. 주문 아이템 분석
#
# ### 2-2. Q1> 브랜드 별 선호도

# %%
# print(df.brandnm.unique())
# print('='*30)
print('클로젯쉐어 전체 브랜드 분류 수 :', len(df.brandnm.unique()))
# Out:
# 클로젯쉐어 전체 브랜드 분류 수 : 246

# %%
df.groupby('brandnm').count()
# Out:
#                  goodsnm  USER  reg_date  order_date  p_type  sub_type  app_yn
# brandnm
# & Other Stories        8     8         8           8       8         8       6
# A BY A                 1     1         1           1       1         1       1
# A.P.C.                 3     3         3           3       3         3       3
# ACNE STUDIOS           4     4         4           4       4         4       4
# Adidas                 1     1         1           1       1         1       1
# ...                  ...   ...       ...         ...     ...       ...     ...
# Zooc                   2     2         2           2       2         2       2
# cecilie bahnsen        1     1         1           1       1         1       1
# khrisjoy               1     1         1           1       1         1       1
# roajeu                 1     1         1           1       1         1       0
# thom browne            1     1         1           1       1         1       0
#
# [245 rows x 7 columns]

# %%
# 구매가 많은 상위 10개 브랜드
df.brandnm.value_counts().sort_values(ascending=False).head(10)

# 수요가 많은 건지, 공급이 많아서 많은 건지.. 
# 구찌가 압도적으로 많은데..
# Out:
# Gucci                 232
# Chanel                 90
# Saint Laurent          86
# Louis Vuitton          79
# Prada                  58
# Burberry               53
# Yves Saint Laurent     38
# Thom Browne            33
# Fendi                  29
# Celine                 28
# Name: brandnm, dtype: int64

# %%
best_br = df.brandnm.value_counts().sort_values(ascending=False).head(10)
plt.figure(figsize=(25,8))
sns.barplot(best_br.index, best_br.values, palette='dark')
plt.grid()
plt.title('상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)
plt.show()

# %%
# 상위 10개 브랜드 sub_type 분포
# br = list(df.brandnm.value_counts().sort_values(ascending=False).head(30))
br = list(df.brandnm.value_counts().sort_values(ascending=False).head(10).index)

f, ax = plt.subplots(5,2 , figsize = (20,30))
axx = ax.flatten()


for axx2, j in zip(axx, br) :
    sns.set_style('whitegrid')
    plt.subplot(axx2)
    b_ca = df[df['brandnm'] == j]
    sns.countplot(data = b_ca, x= 'sub_type', hue='p_type', palette='Accent', ax= axx2)
    plt.title(j, fontsize = 18)

# %% [markdown]
# ### - Top1 : Gucci 데이터만 따로 보기

# %%
# gucci 데이터만 따로 보기
gucci = df.query('brandnm == "Gucci"')[:]
gucci
# Out:
#      brandnm                              goodsnm      USER   reg_date  \
# 0      Gucci   flower dionysus shoulder bag beige   a161237 2019-12-06
# 8      Gucci                   dionysus cross bag  a1143028 2021-01-14
# 16     Gucci  microssima mini cross body bag pink  a1142921 2021-01-14
# 34     Gucci       padlock GG canvas shoulder bag   a143862 2019-09-29
# 36     Gucci                 flap cross bag black  a1141099 2021-01-04
# ...      ...                                  ...       ...        ...
# 1450   Gucci              super mini sylvie white  a1144433 2021-01-25
# 1452   Gucci     vintage web GG two way bag brown  a1117218 2020-08-30
# 1456   Gucci     sylvie mini chain ribbon bag red  a1147961 2021-03-01
# 1457   Gucci      microssima emily mini bag black  a1147942 2021-03-01
# 1459   Gucci  marmont gg logo quilted bag Black 2   a177034 2020-01-23
#
#      order_date p_type sub_type app_yn  order_day
# 0    2021-01-15  7days       BA      Y          4
# 8    2021-01-15  4days       BA      Y          4
# 16   2021-01-14  4days       BA      Y          3
# 34   2021-01-14  4days       BA      Y          3
# 36   2021-01-13  4days       BA      Y          2
# ...         ...    ...      ...    ...        ...
# 1450 2021-03-02  7days       BA      Y          1
# 1452 2021-03-02  7days       BA      Y          1
# 1456 2021-03-01  4days       BA      Y          7
# 1457 2021-03-01  7days       BA      Y          7
# 1459 2021-03-01  4days       BA      Y          7
#
# [232 rows x 9 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=gucci, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=gucci, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=gucci, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=gucci, x='order_day', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Gucci 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### - Top2 : Chanel 데이터만 따로 보기

# %%
Chanel = df.query('brandnm == "Chanel"')[:]
Chanel
# Out:
#      brandnm                                            goodsnm      USER  \
# 28    Chanel  brooch stripe pattern turtle neck turtleneck navy  a1136028
# 58    Chanel            pocket tweed pattern cashmere coat pink  a1138513
# 98    Chanel                   classic chain shoulder bag black  a1141379
# 103   Chanel      pocket basic pattern wool fullzip-jacket grey  a1141288
# 135   Chanel          pocket graphics pattern zipup-jumper navy  a1112031
# ...      ...                                                ...       ...
# 1455  Chanel              stripe pattern pointed cardigan multi  a1147961
# 1458  Chanel                            boy chanel clutch black  a1147960
# 1460  Chanel                  brooch check pattern jacket cream  a1146108
# 1461  Chanel            pocket tweed pattern cashmere coat pink  a1147959
# 1469  Chanel                graphics pattern sweat-shirts white  a1147788
#
#        reg_date order_date p_type sub_type app_yn  order_day
# 28   2020-12-09 2021-01-14  4days        T      Y          3
# 58   2020-12-20 2021-01-11  4days        O      Y          0
# 98   2021-01-06 2021-01-06  7days       BA      Y          2
# 103  2021-01-05 2021-01-06  4days        O      Y          2
# 135  2020-08-15 2021-01-01  7days        O    NaN          7
# ...         ...        ...    ...      ...    ...        ...
# 1455 2021-03-01 2021-03-01  4days        O      Y          7
# 1458 2021-03-01 2021-03-01  7days       BA      Y          7
# 1460 2021-02-11 2021-03-01  7days        O      Y          7
# 1461 2021-03-01 2021-03-01  7days        O    NaN          7
# 1469 2021-02-28 2021-03-01  7days        T      Y          7
#
# [90 rows x 9 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=Chanel, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=Chanel, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=Chanel, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=Chanel, x='order_day', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Chanel 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### - Top3 : Saint Laurent 데이터만 따로 보기

# %%
S_Laurent = df.query('brandnm == "Saint Laurent"')[:]
S_Laurent
# Out:
#             brandnm                            goodsnm      USER   reg_date  \
# 45    Saint Laurent    chevron quilted cross bag black  a1140871 2021-01-02
# 51    Saint Laurent    chevron quilted cross bag black  a1141925 2021-01-09
# 56    Saint Laurent        mini sunset chain bag black  a1142471 2021-01-12
# 67    Saint Laurent  button basic pattern blazer black  a1140758 2021-01-01
# 115   Saint Laurent      quilted calfskin shoulder bag  a1139320 2020-12-22
# ...             ...                                ...       ...        ...
# 1316  Saint Laurent    chevron quilted cross bag black  a1135400 2020-12-05
# 1325  Saint Laurent  monogram mini universal bag black  a1148747 2021-03-09
# 1362  Saint Laurent    chevron quilted cross bag black  a1148129 2021-03-03
# 1382  Saint Laurent      quilted calfskin shoulder bag  a1148237 2021-03-04
# 1388  Saint Laurent    chevron quilted cross bag black  a1148220 2021-03-04
#
#      order_date p_type sub_type app_yn  order_day
# 45   2021-01-13  4days       BA      Y          2
# 51   2021-01-12  4days       BA      Y          1
# 56   2021-01-12  7days       BA      Y          1
# 67   2021-01-10  7days        O      Y          6
# 115  2021-01-05  7days       BA      Y          1
# ...         ...    ...      ...    ...        ...
# 1316 2021-03-09  4days       BA      Y          1
# 1325 2021-03-09  7days       BA      Y          1
# 1362 2021-03-06  7days       BA    NaN          5
# 1382 2021-03-04  4days       BA    NaN          3
# 1388 2021-03-04  7days       BA      Y          3
#
# [86 rows x 9 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=S_Laurent, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=S_Laurent, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=S_Laurent, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=S_Laurent, x='order_day', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Saint Laurent 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### - Top4 : Louis Vuitton 데이터만 따로 보기

# %%
Louis_Vuitton = df.query('brandnm == "Louis Vuitton"')[:]
Louis_Vuitton
# Out:
#             brandnm                                   goodsnm      USER  \
# 10    Louis Vuitton  twist monogram patent shoulder bag black  a1140216
# 44    Louis Vuitton               monogram shoulder bag black   a164734
# 73    Louis Vuitton                alma epi pm tote bag black  a1141816
# 91    Louis Vuitton                     monogram clutch brown  a1141530
# 144   Louis Vuitton                 logo chain tote bag black  a1144704
# ...             ...                                       ...       ...
# 1330  Louis Vuitton         verni mini clutch chain bag brown  a1138484
# 1337  Louis Vuitton                     monogram clutch brown  a1148708
# 1389  Louis Vuitton       galliera gm Shoulder hobo Bag white  a1148221
# 1422  Louis Vuitton         Pochette trunk vertical black bag  a1148115
# 1431  Louis Vuitton                monogram two way bag brown  a1148075
#
#        reg_date order_date p_type sub_type app_yn  order_day
# 10   2020-12-28 2021-01-15  7days       BA      Y          4
# 44   2019-12-13 2021-01-13  4days       BA      Y          2
# 73   2021-01-09 2021-01-09  7days       BA      Y          5
# 91   2021-01-07 2021-01-07  7days       BA      Y          3
# 144  2021-01-27 2021-01-30  4days       BA      Y          5
# ...         ...        ...    ...      ...    ...        ...
# 1330 2020-12-20 2021-03-09  7days       BA      Y          1
# 1337 2021-03-09 2021-03-09  4days       BA      Y          1
# 1389 2021-03-04 2021-03-04  7days       BA      Y          3
# 1422 2021-03-03 2021-03-03  4days       BA      Y          2
# 1431 2021-03-03 2021-03-03  7days       BA      Y          2
#
# [79 rows x 9 columns]

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=Louis_Vuitton, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=Louis_Vuitton, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=Louis_Vuitton, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=Louis_Vuitton, x='order_day', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Louis Vuitton 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### - Top5 : Prada 데이터만 따로 보기

# %%
Prada = df.query('brandnm == "Prada"')[:]
Prada
# Out:
#      brandnm                                            goodsnm      USER  \
# 5      Prada                            ruffle detail long coat   a110231
# 12     Prada                        color fur detail coat black  a1137815
# 13     Prada                  zipper detail cape padding jumper  a1135135
# 15     Prada                                logo hobo bag black  a1143143
# 30     Prada                       quilted cross body bag black  a1142924
# 37     Prada                    single button modern coat black  a1142328
# 48     Prada                       collar point long coat multi   a189599
# 53     Prada  button check pattern wool singlebreasted-jacke...  a1120719
# 123    Prada                          padding two way bag black  a1141018
# 171    Prada                                logo hobo bag black  a1135097
# 176    Prada                   fur detail slim line single coat  a1144764
# 225    Prada                     gradation color padding jumper  a1105887
# 235    Prada                    gold logo crossbody bag hotpink   a168919
# 262    Prada               small logo classic two way bag black  a1144011
# 272    Prada                                saffiano lux M gray  a1143269
# 307    Prada                    button basic pattern coat black  a1143909
# 311    Prada                            striped strap cross bag  a1131731
# 328    Prada          pocket basic pattern padding-outer orange   a112000
# 349    Prada                   quilted chain shoulder bag black   a152462
# 372    Prada                           check pattern lined vest   a160435
# 377    Prada                         high neck robe jumper gray  a1112637
# 409    Prada                             saffiano mini bag blue  a1147227
# 415    Prada                     saffiano cross chain bag black  a1147510
# 416    Prada                  shirring detail two way bag black   a122219
# 445    Prada                saffiano leather mini crossbody bag  a1147237
# 472    Prada                      logo point suede bag burgundy  a1122302
# 553    Prada                      color strap shoulder bag navy  a1146831
# 614    Prada                  zipper detail cape padding jumper  a1146569
# 615    Prada                            striped strap cross bag  a1142928
# 634    Prada                     gradation color padding jumper  a1146458
# 637    Prada                     top handle corssbody bag black  a1135906
# 641    Prada                                pionniere bag brown  a1146306
# 671    Prada                           daino crossbody bag pink   a190885
# 677    Prada                  front button check pattern jacket   a145344
# 702    Prada                            tweed texture chain bag  a1145528
# 769    Prada                        daino crossbody bag black 2  a1145353
# 770    Prada                     saffiano cross chain bag black  a1145165
# 779    Prada                          round neck cardigan beige  a1145279
# 780    Prada                      color strap shoulder bag navy  a1145279
# 782    Prada                           check pattern lined vest  a1110447
# 789    Prada                        medium Nylon Backpack black  a1135783
# 807    Prada                        small logo bucket bag black  a1145039
# 829    Prada                    button basic pattern coat black  a1144978
# 859    Prada                  basic pattern padding-outer black  a1151457
# 968    Prada                          medium Nylon Backpack red  a1150796
# 1021   Prada                    new vit daino shopper bag black  a1145089
# 1104   Prada                            daino shoulder bag skin  a1149583
# 1133   Prada                            striped strap cross bag  a1149667
# 1228   Prada                      logo point suede bag burgundy  a1149465
# 1230   Prada                     saffiano cross chain bag black  a1146676
# 1257   Prada                             saffiano lux chain bag  a1148775
# 1275   Prada                     top handle corssbody bag black  a1148935
# 1294   Prada                saffiano leather mini crossbody bag  a1127412
# 1315   Prada                             quilted belt bag black  a1148428
# 1354   Prada                                logo hobo bag black  a1147639
# 1374   Prada                       unique pattern sweater multi   a175993
# 1432   Prada                      color strap shoulder bag navy  a1148019
# 1467   Prada                                saffiano lux M gray  a1146069
#
#        reg_date order_date p_type sub_type app_yn  order_day
# 5    2018-10-18 2021-01-15  7days        O      Y          4
# 12   2020-12-18 2021-01-15  7days        O      Y          4
# 13   2020-12-04 2021-01-15  7days        O      Y          4
# 15   2021-01-15 2021-01-15  4days       BA      Y          4
# 30   2021-01-14 2021-01-14  4days       BA      Y          3
# 37   2021-01-11 2021-01-13  4days        O      Y          2
# 48   2020-03-22 2021-01-13  7days        O      Y          2
# 53   2020-09-21 2021-01-12  4days        O      Y          1
# 123  2021-01-04 2021-01-04  4days       BA      Y          0
# 171  2020-12-04 2021-01-28  4days       BA      Y          3
# 176  2021-01-28 2021-01-28  4days        O      Y          3
# 225  2020-06-24 2021-01-25  7days        O      Y          0
# 235  2019-12-28 2021-01-25  7days       BA      Y          0
# 262  2021-01-21 2021-01-22  4days       BA      Y          4
# 272  2021-01-15 2021-01-21  4days       BA      Y          3
# 307  2021-01-20 2021-01-20  4days        O    NaN          2
# 311  2020-11-19 2021-01-20  7days       BA      Y          2
# 328  2018-11-24 2021-01-19  4days        O      Y          1
# 349  2019-10-30 2021-01-18  4days       BA      Y          0
# 372  2019-12-03 2021-01-17  4days        T      Y          6
# 377  2020-08-16 2021-02-28  7days        O      Y          6
# 409  2021-02-22 2021-02-25  7days       BA      Y          3
# 415  2021-02-25 2021-02-25  7days       BA      Y          3
# 416  2019-05-08 2021-02-25  4days       BA      Y          3
# 445  2021-02-23 2021-02-24  4days       BA      Y          2
# 472  2020-10-03 2021-02-23  4days       BA      Y          1
# 553  2021-02-18 2021-02-18  4days       BA      Y          3
# 614  2021-02-16 2021-02-16  4days        O      Y          1
# 615  2021-01-14 2021-02-16  7days       BA      Y          1
# 634  2021-02-15 2021-02-15  7days        O      Y          0
# 637  2020-12-08 2021-02-15  7days       BA      Y          0
# 641  2021-02-13 2021-02-14  7days       BA      Y          6
# 671  2020-03-27 2021-02-09  4days       BA      Y          1
# 677  2019-10-05 2021-02-09  4days        O      Y          1
# 702  2021-02-05 2021-02-07  7days       BA      Y          6
# 769  2021-02-03 2021-02-04  4days       BA      Y          3
# 770  2021-02-02 2021-02-04  7days       BA      Y          3
# 779  2021-02-03 2021-02-03  4days        T      Y          2
# 780  2021-02-03 2021-02-03  4days       BA      Y          2
# 782  2020-08-05 2021-02-03  4days        T      Y          2
# 789  2020-12-07 2021-02-03  4days       BA      Y          2
# 807  2021-01-31 2021-02-02  7days       BA      Y          1
# 829  2021-01-31 2021-02-01  7days        O      Y          0
# 859  2021-03-30 2021-03-31  4days        O      Y          2
# 968  2021-03-25 2021-03-25  7days       BA      Y          3
# 1021 2021-02-01 2021-03-24  7days       BA      Y          2
# 1104 2021-03-16 2021-03-19  4days       BA    NaN          4
# 1133 2021-03-16 2021-03-18  4days       BA      Y          3
# 1228 2021-03-15 2021-03-15  7days       BA      Y          0
# 1230 2021-02-17 2021-03-15  4days       BA      Y          0
# 1257 2021-03-09 2021-03-12  7days       BA      Y          4
# 1275 2021-03-11 2021-03-11  7days       BA      Y          3
# 1294 2020-10-28 2021-03-10  4days       BA      Y          2
# 1315 2021-03-06 2021-03-09  4days       BA    NaN          1
# 1354 2021-02-26 2021-03-07  4days       BA      Y          6
# 1374 2020-01-20 2021-03-05  7days        T      Y          4
# 1432 2021-03-02 2021-03-03  7days       BA      Y          2
# 1467 2021-02-11 2021-03-01  7days       BA      Y          7

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=Prada, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=Prada, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=Prada, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=Prada, x='order_day', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('Prada 상품 이용객 분류',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### 2-2. Q2> 아이템 카테고리별 선호도 분석

# %%
f, ax  = plt.subplots(3,1,figsize=(10,15))
plt.subplot(311)
sns.countplot(data=df, x='sub_type')
plt.title('sub_type별 주문 건수')

plt.subplot(312)
sns.countplot(data=df, x='sub_type', hue='p_type')
plt.title('p_type별 주문건')

plt.subplot(313)
sns.countplot(data=df, x='sub_type', hue='order_day')
plt.title('요일별 주문건')

# plt.subplot(224)
# sns.countplot(data=df, x='sub_type', hue='app_yn')
# plt.title('앱 유입여부')

plt.suptitle('아이템 카테고리에 따른 분포',fontsize=30, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### 2-2. Q3> 신규 유저들의 구매 트렌드 파악

# %%
# 신규유저를 어느일을 기준으로 정할 것인지 고민이 필요
# 일단은 올해부터 가입한 사람부터 신규 유저라고 정하겠음.

new_usr = df[df.reg_date > '2020-12-31']
new_usr
# Out:
#                   brandnm                                      goodsnm  \
# 1     El estilo de Claire                   beads cropped jacket black
# 2                   Danha    embroidery point oriental mini skirt blue
# 3                   Danha                    graphics pattern top pink
# 4         Burberry London       buckle basic pattern zipup-jumper navy
# 8                   Gucci                           dionysus cross bag
# ...                   ...                                          ...
# 1464      Burberry London  embroidery basic pattern wool sweater brown
# 1465           London Fog               button basic pattern coat grey
# 1467                Prada                          saffiano lux M gray
# 1468             Burberry                  basic pattern sweater beige
# 1469               Chanel          graphics pattern sweat-shirts white
#
#           USER   reg_date order_date p_type sub_type app_yn  order_day
# 1     a1140859 2021-01-02 2021-01-15  4days        O    NaN          4
# 2     a1140859 2021-01-02 2021-01-15  4days        B    NaN          4
# 3     a1140859 2021-01-02 2021-01-15  4days        T    NaN          4
# 4     a1140740 2021-01-01 2021-01-15  7days        O      Y          4
# 8     a1143028 2021-01-14 2021-01-15  4days       BA      Y          4
# ...        ...        ...        ...    ...      ...    ...        ...
# 1464  a1147932 2021-03-01 2021-03-01  4days        T      Y          7
# 1465  a1147932 2021-03-01 2021-03-01  4days        O      Y          7
# 1467  a1146069 2021-02-11 2021-03-01  7days       BA      Y          7
# 1468  a1147848 2021-02-28 2021-03-01  7days        T      Y          7
# 1469  a1147788 2021-02-28 2021-03-01  7days        T      Y          7
#
# [981 rows x 9 columns]

# %%
max(new_usr.order_date - new_usr.reg_date)
min(new_usr.order_date - new_usr.reg_date)
new_usr.order_date - new_usr.reg_date
# Out:
# 1      13 days
# 2      13 days
# 3      13 days
# 4      14 days
# 8       1 days
#          ...
# 1464    0 days
# 1465    0 days
# 1467   18 days
# 1468    1 days
# 1469    1 days
# Length: 981, dtype: timedelta64[ns]

# %%
# 2021년 가입자 선호 브랜드
new_usr.brandnm.value_counts().sort_values(ascending=False).head(10)
# Out:
# Gucci                 166
# Saint Laurent          66
# Chanel                 65
# Louis Vuitton          61
# Prada                  36
# Burberry               33
# Yves Saint Laurent     24
# Celine                 22
# Thom Browne            19
# Fendi                  19
# Name: brandnm, dtype: int64

# %%
old_usr = df[df.reg_date <= '2020-12-31']
old_usr
# Out:
#                  brandnm                                  goodsnm      USER  \
# 0                  Gucci       flower dionysus shoulder bag beige   a161237
# 5                  Prada                  ruffle detail long coat   a110231
# 6               Max Mara      strap basic pattern wrap-coat black  a1139960
# 7              Molliolli     pocket basic pattern fur-outer ivory   a115159
# 9                 Sandro           pattern pointed cardigan black   a117306
# ...                  ...                                      ...       ...
# 1454            Burberry  button basic pattern wool cardigan grey   a163815
# 1459               Gucci      marmont gg logo quilted bag Black 2   a177034
# 1462            Max Mara            zipper detail two tone jacket   a112319
# 1466  Yves Saint Laurent               logo point clutch bag pink   a119721
# 1470            Burberry                classic trench coat beige   a190054
#
#        reg_date order_date p_type sub_type app_yn  order_day
# 0    2019-12-06 2021-01-15  7days       BA      Y          4
# 5    2018-10-18 2021-01-15  7days        O      Y          4
# 6    2020-12-26 2021-01-15  7days        O      Y          4
# 7    2019-01-29 2021-01-15  4days        O      Y          4
# 9    2019-03-02 2021-01-15  7days        O      Y          4
# ...         ...        ...    ...      ...    ...        ...
# 1454 2019-12-12 2021-03-01  7days        O      Y          7
# 1459 2020-01-23 2021-03-01  4days       BA      Y          7
# 1462 2018-11-29 2021-03-01  4days        O      Y          7
# 1466 2019-04-10 2021-03-01  7days       BA      Y          7
# 1470 2020-03-24 2021-03-01  4days        O      Y          7
#
# [485 rows x 9 columns]

# %%
# 2021년 이전 가입자 선호 브랜드
old_usr.brandnm.value_counts().sort_values(ascending=False).head(10)
# Out:
# Gucci                 64
# Chanel                25
# Prada                 22
# Saint Laurent         20
# Burberry              20
# Louis Vuitton         18
# Thom Browne           14
# Yves Saint Laurent    14
# Max Mara              12
# Sandro                11
# Name: brandnm, dtype: int64

# %%
new_br = new_usr.brandnm.value_counts().sort_values(ascending=False).head(10)
old_br = old_usr.brandnm.value_counts().sort_values(ascending=False).head(10)

plt.subplots(2,1,figsize=(20,12))
plt.subplot(211)
sns.barplot(new_br.index, new_br.values, palette='dark')
plt.title('신규 유저 상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)

plt.subplot(212)
sns.barplot(old_br.index, old_br.values)
plt.title('기존 유저 상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)
plt.show()

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=new_usr, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=new_usr, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=new_usr, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=new_usr, x='order_day', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('2021년 가입자 동향',fontsize=30, fontweight = 'bold')
plt.show()

# %%
f, ax  = plt.subplots(2,2,figsize=(15,10))
plt.subplot(221)
sns.countplot(data=old_usr, x='order_day')
plt.title('요일별 주문 건수')

plt.subplot(222)
sns.countplot(data=old_usr, x='p_type')
plt.title('p_type별 주문건')

plt.subplot(223)
sns.countplot(data=old_usr, x='sub_type')
plt.title('sub_type별 주문건')

plt.subplot(224)
sns.countplot(data=old_usr, x='order_day', hue='app_yn')
plt.title('요일별 앱 유입여부')

plt.suptitle('기존(2021이전) 가입자 동향',fontsize=30, fontweight = 'bold')
plt.show()
